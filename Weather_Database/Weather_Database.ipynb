# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-91.000, high=91.000, size=2000)
lngs = np.random.uniform(low=-191.000, high=181.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 737

# %%
import requests
from config import weather_api_key

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=' + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1



# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_min_temp = city_weather["main"]["temp_min"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Min Temp": city_min_temp,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 15 | port alfred
# Processing Record 2 of Set 15 | nantucket
# Processing Record 3 of Set 15 | prince albert
# Processing Record 4 of Set 15 | vaini
# Processing Record 5 of Set 15 | berlevag
# Processing Record 6 of Set 15 | taltal
# Processing Record 7 of Set 15 | manicore
# Processing Record 8 of Set 15 | eucaliptus
# Processing Record 9 of Set 15 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 15 | tilichiki
# Processing Record 11 of Set 15 | cape town
# Processing Record 12 of Set 15 | okhotsk
# Processing Record 13 of Set 15 | te anau
# Processing Record 14 of Set 15 | albany
# Processing Record 15 of Set 15 | punta arenas
# Processing Record 16 of Set 15 | nemuro
# Processing Record 17 of Set 15 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 15 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 15 | isangel
# Processing Record 20 of Set 15 | hithadhoo
# Processing Record 21 of Set 15 | tuktoyaktuk
# Processing Record 22 of Set 15 | flinders
# Processing Record 23 of Set 15 | ayios matthaios
# City not found. Skipping...
# Processing Record 24 of Set 15 | bredasdorp
# Processing Record 25 of Set 15 | ushuaia
# Processing Record 26 of Set 15 | krasnoselkup
# Processing Record 27 of Set 15 | dejen
# Processing Record 28 of Set 15 | aden
# Processing Record 29 of Set 15 | ponta do sol
# Processing Record 30 of Set 15 | hilo
# Processing Record 31 of Set 15 | coquimbo
# Processing Record 32 of Set 15 | atuona
# Processing Record 33 of Set 15 | san juan
# Processing Record 34 of Set 15 | meiktila
# Processing Record 35 of Set 15 | anadyr
# Processing Record 36 of Set 15 | puteyets
# Processing Record 37 of Set 15 | bluff
# Processing Record 38 of Set 15 | new norfolk
# Processing Record 39 of Set 15 | qaanaaq
# Processing Record 40 of Set 15 | rikitea
# Processing Record 41 of Set 15 | provideniya
# Processing Record 42 of Set 15 | busselton
# Processing Record 43 of Set 15 | mataura
# Processing Record 44 of Set 15 | kamloops
# Processing Record 45 of Set 15 | north battleford
# Processing Record 46 of Set 15 | mar del plata
# Processing Record 47 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 48 of Set 15 | arraial do cabo
# Processing Record 49 of Set 15 | esperance
# Processing Record 50 of Set 15 | hay river
# Processing Record 1 of Set 16 | sfantu gheorghe
# Processing Record 2 of Set 16 | sur
# Processing Record 3 of Set 16 | otelu rosu
# Processing Record 4 of Set 16 | ribeira grande
# Processing Record 5 of Set 16 | jamestown
# Processing Record 6 of Set 16 | nikolskoye
# Processing Record 7 of Set 16 | birjand
# Processing Record 8 of Set 16 | fairbanks
# Processing Record 9 of Set 16 | longyearbyen
# Processing Record 10 of Set 16 | upernavik
# Processing Record 11 of Set 16 | aklavik
# Processing Record 12 of Set 16 | tiksi
# Processing Record 13 of Set 16 | kapaa
# Processing Record 14 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 16 | saint-philippe
# Processing Record 16 of Set 16 | antigonish
# Processing Record 17 of Set 16 | ornskoldsvik
# Processing Record 18 of Set 16 | benguela
# Processing Record 19 of Set 16 | sao filipe
# Processing Record 20 of Set 16 | san cristobal
# Processing Record 21 of Set 16 | zaysan
# Processing Record 22 of Set 16 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 16 | bethel
# Processing Record 24 of Set 16 | mount gambier
# Processing Record 25 of Set 16 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 26 of Set 16 | sitka
# Processing Record 27 of Set 16 | issia
# Processing Record 28 of Set 16 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 16 | sibolga
# Processing Record 30 of Set 16 | baykit
# Processing Record 31 of Set 16 | ekibastuz
# Processing Record 32 of Set 16 | bambous virieux
# Processing Record 33 of Set 16 | lianzhou
# Processing Record 34 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 16 | norman wells
# Processing Record 36 of Set 16 | itoman
# Processing Record 37 of Set 16 | palmer
# Processing Record 38 of Set 16 | ferrol
# Processing Record 39 of Set 16 | daugai
# Processing Record 40 of Set 16 | la ronge
# Processing Record 41 of Set 16 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 16 | hermanus
# Processing Record 43 of Set 16 | solginskiy
# Processing Record 44 of Set 16 | tasbuget
# City not found. Skipping...
# Processing Record 45 of Set 16 | shelburne
# Processing Record 46 of Set 16 | rexburg
# Processing Record 47 of Set 16 | cockburn town
# Processing Record 48 of Set 16 | kozhva
# Processing Record 49 of Set 16 | tvoroyri
# Processing Record 50 of Set 16 | leningradskiy
# Processing Record 1 of Set 17 | am timan
# Processing Record 2 of Set 17 | bunbury
# Processing Record 3 of Set 17 | micomeseng
# Processing Record 4 of Set 17 | svetlogorsk
# Processing Record 5 of Set 17 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 17 | bubaque
# Processing Record 7 of Set 17 | dingle
# Processing Record 8 of Set 17 | turukhansk
# Processing Record 9 of Set 17 | east london
# Processing Record 10 of Set 17 | yulara
# Processing Record 11 of Set 17 | teahupoo
# Processing Record 12 of Set 17 | jieshi
# Processing Record 13 of Set 17 | mountain home
# Processing Record 14 of Set 17 | ruatoria
# City not found. Skipping...
# Processing Record 15 of Set 17 | campina grande do sul
# Processing Record 16 of Set 17 | redmond
# Processing Record 17 of Set 17 | thompson
# Processing Record 18 of Set 17 | hobart
# Processing Record 19 of Set 17 | mahebourg
# Processing Record 20 of Set 17 | sao joao da barra
# Processing Record 21 of Set 17 | kieta
# Processing Record 22 of Set 17 | warrnambool
# Processing Record 23 of Set 17 | asosa
# Processing Record 24 of Set 17 | rocha
# Processing Record 25 of Set 17 | kodiak
# Processing Record 26 of Set 17 | acapulco
# Processing Record 27 of Set 17 | georgetown
# Processing Record 28 of Set 17 | azanka
# Processing Record 29 of Set 17 | severo-kurilsk
# Processing Record 30 of Set 17 | dukat
# Processing Record 31 of Set 17 | egvekinot
# Processing Record 32 of Set 17 | namibe
# Processing Record 33 of Set 17 | kloulklubed
# Processing Record 34 of Set 17 | khatanga
# Processing Record 35 of Set 17 | ughelli
# Processing Record 36 of Set 17 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 17 | lompoc
# Processing Record 38 of Set 17 | oltu
# Processing Record 39 of Set 17 | fuyang
# Processing Record 40 of Set 17 | lazaro cardenas
# Processing Record 41 of Set 17 | puerto ayora
# Processing Record 42 of Set 17 | chokurdakh
# Processing Record 43 of Set 17 | monitos
# Processing Record 44 of Set 17 | matara
# Processing Record 45 of Set 17 | dunedin
# Processing Record 46 of Set 17 | sterlitamak
# Processing Record 47 of Set 17 | avarua
# Processing Record 48 of Set 17 | victoria
# Processing Record 49 of Set 17 | port elizabeth
# Processing Record 50 of Set 17 | tautira
# Processing Record 1 of Set 18 | praia
# Processing Record 2 of Set 18 | paamiut
# Processing Record 3 of Set 18 | bengkulu
# Processing Record 4 of Set 18 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 18 | segezha
# Processing Record 6 of Set 18 | port hardy
# Processing Record 7 of Set 18 | zadar
# Processing Record 8 of Set 18 | elmina
# Processing Record 9 of Set 18 | fuxin
# Processing Record 10 of Set 18 | valreas
# Processing Record 11 of Set 18 | atar
# Processing Record 12 of Set 18 | lamu
# Processing Record 13 of Set 18 | luderitz
# Processing Record 14 of Set 18 | vostok
# Processing Record 15 of Set 18 | bunia
# Processing Record 16 of Set 18 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 18 | katsuura
# Processing Record 18 of Set 18 | rio claro
# Processing Record 19 of Set 18 | oktyabrskiy
# Processing Record 20 of Set 18 | rio grande
# Processing Record 21 of Set 18 | padang
# Processing Record 22 of Set 18 | kuttigen
# Processing Record 23 of Set 18 | rapid city
# Processing Record 24 of Set 18 | ishigaki
# Processing Record 25 of Set 18 | elliot
# Processing Record 26 of Set 18 | charlestown
# Processing Record 27 of Set 18 | halifax
# Processing Record 28 of Set 18 | nsanje
# Processing Record 29 of Set 18 | moerai
# Processing Record 30 of Set 18 | fort nelson
# Processing Record 31 of Set 18 | cabedelo
# Processing Record 32 of Set 18 | mnogovershinnyy
# Processing Record 33 of Set 18 | komsomolskiy
# Processing Record 34 of Set 18 | jhabua
# Processing Record 35 of Set 18 | sinnamary
# Processing Record 36 of Set 18 | fukuma
# Processing Record 37 of Set 18 | ixtapa
# Processing Record 38 of Set 18 | qianan
# Processing Record 39 of Set 18 | barrow
# Processing Record 40 of Set 18 | sa kaeo
# Processing Record 41 of Set 18 | zhangjiakou
# Processing Record 42 of Set 18 | banda aceh
# Processing Record 43 of Set 18 | sola
# Processing Record 44 of Set 18 | sioux lookout
# Processing Record 45 of Set 18 | nioro
# Processing Record 46 of Set 18 | nouadhibou
# Processing Record 47 of Set 18 | touros
# Processing Record 48 of Set 18 | muborak
# Processing Record 49 of Set 18 | nuevitas
# Processing Record 50 of Set 18 | guerrero negro
# Processing Record 1 of Set 19 | sladkovo
# Processing Record 2 of Set 19 | urumqi
# Processing Record 3 of Set 19 | kalabo
# Processing Record 4 of Set 19 | tchollire
# Processing Record 5 of Set 19 | kirakira
# Processing Record 6 of Set 19 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 19 | ahipara
# Processing Record 8 of Set 19 | tshikapa
# Processing Record 9 of Set 19 | sakakah
# Processing Record 10 of Set 19 | ilulissat
# Processing Record 11 of Set 19 | gambissara
# Processing Record 12 of Set 19 | skjervoy
# Processing Record 13 of Set 19 | cidreira
# Processing Record 14 of Set 19 | lethem
# Processing Record 15 of Set 19 | praya
# Processing Record 16 of Set 19 | zhaodong
# Processing Record 17 of Set 19 | shingu
# Processing Record 18 of Set 19 | port macquarie
# Processing Record 19 of Set 19 | cooma
# Processing Record 20 of Set 19 | sanming
# Processing Record 21 of Set 19 | luanda
# Processing Record 22 of Set 19 | eskisehir
# Processing Record 23 of Set 19 | codrington
# Processing Record 24 of Set 19 | saskylakh
# Processing Record 25 of Set 19 | yokadouma
# Processing Record 26 of Set 19 | zhezkazgan
# Processing Record 27 of Set 19 | carnarvon
# Processing Record 28 of Set 19 | vila franca do campo
# Processing Record 29 of Set 19 | caceres
# Processing Record 30 of Set 19 | pevek
# Processing Record 31 of Set 19 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 19 | kamsack
# Processing Record 33 of Set 19 | saint-augustin
# Processing Record 34 of Set 19 | capao da canoa
# Processing Record 35 of Set 19 | laredo
# Processing Record 36 of Set 19 | oil city
# Processing Record 37 of Set 19 | pisco
# Processing Record 38 of Set 19 | porto santo
# Processing Record 39 of Set 19 | ketchikan
# Processing Record 40 of Set 19 | dinsor
# City not found. Skipping...
# Processing Record 41 of Set 19 | sebezh
# Processing Record 42 of Set 19 | shenkursk
# Processing Record 43 of Set 19 | stoyba
# City not found. Skipping...
# Processing Record 44 of Set 19 | tabou
# Processing Record 45 of Set 19 | sayyan
# Processing Record 46 of Set 19 | satitoa
# City not found. Skipping...
# Processing Record 47 of Set 19 | camacha
# Processing Record 48 of Set 19 | yellowknife
# Processing Record 49 of Set 19 | kharovsk
# Processing Record 50 of Set 19 | hamilton
# Processing Record 1 of Set 20 | baghdad
# Processing Record 2 of Set 20 | ewa beach
# Processing Record 3 of Set 20 | saint george
# Processing Record 4 of Set 20 | butaritari
# Processing Record 5 of Set 20 | puerto escondido
# Processing Record 6 of Set 20 | shimoda
# Processing Record 7 of Set 20 | morondava
# Processing Record 8 of Set 20 | halalo
# City not found. Skipping...
# Processing Record 9 of Set 20 | berezovka
# Processing Record 10 of Set 20 | rawson
# Processing Record 11 of Set 20 | dikson
# Processing Record 12 of Set 20 | terrace
# Processing Record 13 of Set 20 | mogadishu
# Processing Record 14 of Set 20 | pasni
# Processing Record 15 of Set 20 | lorengau
# Processing Record 16 of Set 20 | vardo
# Processing Record 17 of Set 20 | geraldton
# Processing Record 18 of Set 20 | gigmoto
# Processing Record 19 of Set 20 | kintampo
# Processing Record 20 of Set 20 | port lincoln
# Processing Record 21 of Set 20 | flagstaff
# Processing Record 22 of Set 20 | nortelandia
# Processing Record 23 of Set 20 | kruisfontein
# Processing Record 24 of Set 20 | alvorada
# Processing Record 25 of Set 20 | manzil tamim
# City not found. Skipping...
# Processing Record 26 of Set 20 | airai
# Processing Record 27 of Set 20 | chapais
# Processing Record 28 of Set 20 | chara
# Processing Record 29 of Set 20 | wajid
# Processing Record 30 of Set 20 | spas-demensk
# Processing Record 31 of Set 20 | olafsvik
# Processing Record 32 of Set 20 | scarborough
# Processing Record 33 of Set 20 | santa cruz
# Processing Record 34 of Set 20 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 20 | ploemeur
# Processing Record 36 of Set 20 | ladario
# Processing Record 37 of Set 20 | san policarpo
# Processing Record 38 of Set 20 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 20 | mayo
# Processing Record 40 of Set 20 | chelmno
# Processing Record 41 of Set 20 | kalawit
# Processing Record 42 of Set 20 | inverell
# Processing Record 43 of Set 20 | ancud
# Processing Record 44 of Set 20 | malwan
# City not found. Skipping...
# Processing Record 45 of Set 20 | cherdyn
# Processing Record 46 of Set 20 | kapustin yar
# Processing Record 47 of Set 20 | hasaki
# Processing Record 48 of Set 20 | sinkat
# City not found. Skipping...
# Processing Record 49 of Set 20 | clyde river
# Processing Record 50 of Set 20 | newport
# Processing Record 1 of Set 21 | port-gentil
# Processing Record 2 of Set 21 | nguiu
# City not found. Skipping...
# Processing Record 3 of Set 21 | anori
# Processing Record 4 of Set 21 | bilibino
# Processing Record 5 of Set 21 | beringovskiy
# Processing Record 6 of Set 21 | verkhoyansk
# Processing Record 7 of Set 21 | viedma
# Processing Record 8 of Set 21 | saldanha
# Processing Record 9 of Set 21 | corrente
# Processing Record 10 of Set 21 | matamoros
# Processing Record 11 of Set 21 | novikovo
# Processing Record 12 of Set 21 | mitsamiouli
# Processing Record 13 of Set 21 | urambo
# Processing Record 14 of Set 21 | ahuimanu
# Processing Record 15 of Set 21 | lavrentiya
# Processing Record 16 of Set 21 | khash
# Processing Record 17 of Set 21 | westport
# Processing Record 18 of Set 21 | banihal
# Processing Record 19 of Set 21 | mahadday weyne
# City not found. Skipping...
# Processing Record 20 of Set 21 | batetskiy
# Processing Record 21 of Set 21 | saint-francois
# Processing Record 22 of Set 21 | shanhetun
# Processing Record 23 of Set 21 | warmbad
# Processing Record 24 of Set 21 | san patricio
# Processing Record 25 of Set 21 | tarudant
# City not found. Skipping...
# Processing Record 26 of Set 21 | lebu
# Processing Record 27 of Set 21 | nyandoma
# Processing Record 28 of Set 21 | montijo
# Processing Record 29 of Set 21 | trairi
# Processing Record 30 of Set 21 | yar-sale
# Processing Record 31 of Set 21 | vung tau
# Processing Record 32 of Set 21 | fort saint james
# Processing Record 33 of Set 21 | kazanskoye
# Processing Record 34 of Set 21 | ormara
# Processing Record 35 of Set 21 | sokoni
# Processing Record 36 of Set 21 | tura
# Processing Record 37 of Set 21 | necochea
# Processing Record 38 of Set 21 | lage
# Processing Record 39 of Set 21 | khormuj
# City not found. Skipping...
# Processing Record 40 of Set 21 | henties bay
# Processing Record 41 of Set 21 | maldonado
# Processing Record 42 of Set 21 | jacareacanga
# Processing Record 43 of Set 21 | ipira
# Processing Record 44 of Set 21 | la suiza
# Processing Record 45 of Set 21 | gerash
# Processing Record 46 of Set 21 | inderborskiy
# City not found. Skipping...
# Processing Record 47 of Set 21 | eureka
# Processing Record 48 of Set 21 | iqaluit
# Processing Record 49 of Set 21 | bayangol
# Processing Record 50 of Set 21 | lazi
# Processing Record 1 of Set 22 | maragogi
# Processing Record 2 of Set 22 | pimenta bueno
# Processing Record 3 of Set 22 | poum
# Processing Record 4 of Set 22 | alpena
# Processing Record 5 of Set 22 | half moon bay
# Processing Record 6 of Set 22 | hope
# Processing Record 7 of Set 22 | nuuk
# Processing Record 8 of Set 22 | algiers
# Processing Record 9 of Set 22 | tortoli
# Processing Record 10 of Set 22 | deputatskiy
# Processing Record 11 of Set 22 | mizdah
# Processing Record 12 of Set 22 | khandyga
# Processing Record 13 of Set 22 | alugan
# Processing Record 14 of Set 22 | auki
# Processing Record 15 of Set 22 | iskateley
# Processing Record 16 of Set 22 | myitkyina
# Processing Record 17 of Set 22 | torrox
# Processing Record 18 of Set 22 | keokuk
# Processing Record 19 of Set 22 | haibowan
# City not found. Skipping...
# Processing Record 20 of Set 22 | beyneu
# Processing Record 21 of Set 22 | kaohsiung
# Processing Record 22 of Set 22 | toora-khem
# Processing Record 23 of Set 22 | bonavista
# Processing Record 24 of Set 22 | sterling
# Processing Record 25 of Set 22 | harper
# Processing Record 26 of Set 22 | kendari
# Processing Record 27 of Set 22 | sobolevo
# Processing Record 28 of Set 22 | nome
# Processing Record 29 of Set 22 | bhunya
# Processing Record 30 of Set 22 | torbay
# Processing Record 31 of Set 22 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 22 | pangnirtung
# Processing Record 33 of Set 22 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 22 | masaka
# Processing Record 35 of Set 22 | darhan
# Processing Record 36 of Set 22 | seydi
# Processing Record 37 of Set 22 | narsaq
# Processing Record 38 of Set 22 | yarada
# Processing Record 39 of Set 22 | tocopilla
# Processing Record 40 of Set 22 | nelson bay
# Processing Record 41 of Set 22 | chuy
# Processing Record 42 of Set 22 | wuwei
# Processing Record 43 of Set 22 | liverpool
# Processing Record 44 of Set 22 | gazli
# Processing Record 45 of Set 22 | nanortalik
# Processing Record 46 of Set 22 | champoton
# Processing Record 47 of Set 22 | jardim
# Processing Record 48 of Set 22 | khetia
# Processing Record 49 of Set 22 | thyboron
# Processing Record 50 of Set 22 | mbini
# Processing Record 1 of Set 23 | waingapu
# Processing Record 2 of Set 23 | jiddah
# City not found. Skipping...
# Processing Record 3 of Set 23 | havre-saint-pierre
# Processing Record 4 of Set 23 | barretos
# Processing Record 5 of Set 23 | pacific grove
# Processing Record 6 of Set 23 | leh
# Processing Record 7 of Set 23 | veraval
# Processing Record 8 of Set 23 | haines junction
# Processing Record 9 of Set 23 | kavieng
# Processing Record 10 of Set 23 | labuhan
# Processing Record 11 of Set 23 | castro
# Processing Record 12 of Set 23 | tasiilaq
# Processing Record 13 of Set 23 | quesnel
# Processing Record 14 of Set 23 | banjar
# Processing Record 15 of Set 23 | radyvyliv
# Processing Record 16 of Set 23 | litoral del san juan
# City not found. Skipping...
# Processing Record 17 of Set 23 | aykhal
# Processing Record 18 of Set 23 | brae
# Processing Record 19 of Set 23 | suoyarvi
# Processing Record 20 of Set 23 | platanos
# Processing Record 21 of Set 23 | atbasar
# Processing Record 22 of Set 23 | atyrau
# Processing Record 23 of Set 23 | williams lake
# Processing Record 24 of Set 23 | oktyabrskoye
# Processing Record 25 of Set 23 | kamenka
# Processing Record 26 of Set 23 | cherskiy
# Processing Record 27 of Set 23 | motihari
# Processing Record 28 of Set 23 | sawakin
# Processing Record 29 of Set 23 | adrar
# Processing Record 30 of Set 23 | troitsk
# Processing Record 31 of Set 23 | kegayli
# City not found. Skipping...
# Processing Record 32 of Set 23 | asau
# Processing Record 33 of Set 23 | prince rupert
# Processing Record 34 of Set 23 | kapuskasing
# Processing Record 35 of Set 23 | saint-pierre
# Processing Record 36 of Set 23 | san quintin
# Processing Record 37 of Set 23 | cuamba
# Processing Record 38 of Set 23 | sao felix do xingu
# Processing Record 39 of Set 23 | karratha
# Processing Record 40 of Set 23 | carora
# Processing Record 41 of Set 23 | waipawa
# Processing Record 42 of Set 23 | coahuayana
# Processing Record 43 of Set 23 | camapua
# Processing Record 44 of Set 23 | srednekolymsk
# Processing Record 45 of Set 23 | cape coast
# Processing Record 46 of Set 23 | kargasok
# Processing Record 47 of Set 23 | qasigiannguit
# Processing Record 48 of Set 23 | ndele
# Processing Record 49 of Set 23 | puerto narino
# Processing Record 50 of Set 23 | verkhniy avzyan
# Processing Record 1 of Set 24 | saint-jean-de-maurienne
# Processing Record 2 of Set 24 | hobyo
# Processing Record 3 of Set 24 | maralal
# Processing Record 4 of Set 24 | beloha
# Processing Record 5 of Set 24 | saint-joseph
# Processing Record 6 of Set 24 | pinar del rio
# Processing Record 7 of Set 24 | sept-iles
# Processing Record 8 of Set 24 | barabai
# Processing Record 9 of Set 24 | klaebu
# Processing Record 10 of Set 24 | reitz
# Processing Record 11 of Set 24 | ust-ilimsk
# Processing Record 12 of Set 24 | ternate
# Processing Record 13 of Set 24 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 24 | jozefow
# Processing Record 15 of Set 24 | kavaratti
# Processing Record 16 of Set 24 | ozinki
# Processing Record 17 of Set 24 | hofn
# Processing Record 18 of Set 24 | talnakh
# Processing Record 19 of Set 24 | quatre cocos
# Processing Record 20 of Set 24 | oakland
# Processing Record 21 of Set 24 | igrim
# Processing Record 22 of Set 24 | gamba
# Processing Record 23 of Set 24 | souillac
# Processing Record 24 of Set 24 | kautokeino
# Processing Record 25 of Set 24 | meulaboh
# Processing Record 26 of Set 24 | krasnyy chikoy
# Processing Record 27 of Set 24 | mongar
# Processing Record 28 of Set 24 | noumea
# Processing Record 29 of Set 24 | ugoofaaru
# Processing Record 30 of Set 24 | kaitangata
# Processing Record 31 of Set 24 | synya
# Processing Record 32 of Set 24 | roald
# Processing Record 33 of Set 24 | ranot
# Processing Record 34 of Set 24 | srandakan
# Processing Record 35 of Set 24 | katherine
# Processing Record 36 of Set 24 | sanmenxia
# Processing Record 37 of Set 24 | peniche
# Processing Record 38 of Set 24 | somerset east
# Processing Record 39 of Set 24 | ust-kulom
# Processing Record 40 of Set 24 | los llanos de aridane
# Processing Record 41 of Set 24 | atasu
# Processing Record 42 of Set 24 | kenai
# Processing Record 43 of Set 24 | pahrump
# Processing Record 44 of Set 24 | port-cartier
# Processing Record 45 of Set 24 | qafsah
# City not found. Skipping...
# Processing Record 46 of Set 24 | fortuna
# Processing Record 47 of Set 24 | bathsheba
# Processing Record 48 of Set 24 | gangawati
# Processing Record 49 of Set 24 | pangoa
# Processing Record 50 of Set 24 | margate
# Processing Record 1 of Set 25 | sussex
# Processing Record 2 of Set 25 | grindavik
# Processing Record 3 of Set 25 | north bend
# Processing Record 4 of Set 25 | galle
# Processing Record 5 of Set 25 | villagarzon
# Processing Record 6 of Set 25 | bitkine
# Processing Record 7 of Set 25 | puerto montt
# Processing Record 8 of Set 25 | bowen
# Processing Record 9 of Set 25 | kasane
# Processing Record 10 of Set 25 | naukot
# Processing Record 11 of Set 25 | ziro
# Processing Record 12 of Set 25 | yaan
# Processing Record 13 of Set 25 | odemis
# City not found. Skipping...
# Processing Record 14 of Set 25 | santa cruz de tenerife
# Processing Record 15 of Set 25 | copandaro
# City not found. Skipping...
# Processing Record 16 of Set 25 | svetlyy
# Processing Record 17 of Set 25 | sisimiut
# Processing Record 18 of Set 25 | stornoway
# Processing Record 19 of Set 25 | weligama
# Processing Record 20 of Set 25 | araouane
# Processing Record 21 of Set 25 | dakar
# Processing Record 22 of Set 25 | prior lake
# Processing Record 23 of Set 25 | bac lieu
# Processing Record 24 of Set 25 | ambilobe
# Processing Record 25 of Set 25 | huesca
# Processing Record 26 of Set 25 | laguna
# Processing Record 27 of Set 25 | vestmannaeyjar
# Processing Record 28 of Set 25 | bacolod
# Processing Record 29 of Set 25 | salalah
# Processing Record 30 of Set 25 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 25 | emerald
# Processing Record 32 of Set 25 | the valley
# Processing Record 33 of Set 25 | todos santos
# Processing Record 34 of Set 25 | kijang
# Processing Record 35 of Set 25 | aripuana
# Processing Record 36 of Set 25 | santa maria
# Processing Record 37 of Set 25 | devonport
# Processing Record 38 of Set 25 | buon me thuot
# City not found. Skipping...
# Processing Record 39 of Set 25 | khani
# Processing Record 40 of Set 25 | fomboni
# Processing Record 41 of Set 25 | wuxue
# Processing Record 42 of Set 25 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 43 of Set 25 | san andres
# Processing Record 44 of Set 25 | bridgeton
# Processing Record 45 of Set 25 | tingrela
# City not found. Skipping...
# Processing Record 46 of Set 25 | constitucion
# Processing Record 47 of Set 25 | naze
# Processing Record 48 of Set 25 | saint anthony
# Processing Record 49 of Set 25 | athabasca
# Processing Record 50 of Set 25 | faya
# Processing Record 1 of Set 26 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 26 | springfield
# Processing Record 3 of Set 26 | shirokiy
# Processing Record 4 of Set 26 | nishihara
# Processing Record 5 of Set 26 | ulladulla
# Processing Record 6 of Set 26 | kazanskaya
# Processing Record 7 of Set 26 | gao
# Processing Record 8 of Set 26 | salinopolis
# Processing Record 9 of Set 26 | coihaique
# Processing Record 10 of Set 26 | baiquan
# Processing Record 11 of Set 26 | pyaozerskiy
# Processing Record 12 of Set 26 | bandarbeyla
# Processing Record 13 of Set 26 | maicao
# Processing Record 14 of Set 26 | hualmay
# Processing Record 15 of Set 26 | mbuguni
# Processing Record 16 of Set 26 | okha
# Processing Record 17 of Set 26 | batagay-alyta
# Processing Record 18 of Set 26 | barzas
# Processing Record 19 of Set 26 | port said
# Processing Record 20 of Set 26 | knoxville
# Processing Record 21 of Set 26 | sharon
# Processing Record 22 of Set 26 | linqing
# Processing Record 23 of Set 26 | babanusah
# City not found. Skipping...
# Processing Record 24 of Set 26 | baldeogarh
# Processing Record 25 of Set 26 | san ramon
# Processing Record 26 of Set 26 | altay
# Processing Record 27 of Set 26 | hovd
# Processing Record 28 of Set 26 | qandala
# Processing Record 29 of Set 26 | dire
# Processing Record 30 of Set 26 | caravelas
# Processing Record 31 of Set 26 | galgani
# City not found. Skipping...
# Processing Record 32 of Set 26 | isetskoye
# Processing Record 33 of Set 26 | kargat
# Processing Record 34 of Set 26 | batsfjord
# Processing Record 35 of Set 26 | verkhnevilyuysk
# Processing Record 36 of Set 26 | aquiraz
# Processing Record 37 of Set 26 | humaita
# Processing Record 38 of Set 26 | prachuap khiri khan
# Processing Record 39 of Set 26 | morant bay
# Processing Record 40 of Set 26 | sangar
# Processing Record 41 of Set 26 | broken hill
# Processing Record 42 of Set 26 | tevriz
# Processing Record 43 of Set 26 | gangotri
# City not found. Skipping...
# Processing Record 44 of Set 26 | council bluffs
# Processing Record 45 of Set 26 | cabinda
# Processing Record 46 of Set 26 | kharp
# Processing Record 47 of Set 26 | burgeo
# Processing Record 48 of Set 26 | graciano sanchez
# Processing Record 49 of Set 26 | aswan
# Processing Record 50 of Set 26 | longlac
# City not found. Skipping...
# Processing Record 1 of Set 27 | lasa
# Processing Record 2 of Set 27 | oliveira dos brejinhos
# Processing Record 3 of Set 27 | umm kaddadah
# Processing Record 4 of Set 27 | montanha
# Processing Record 5 of Set 27 | lisakovsk
# Processing Record 6 of Set 27 | cabo san lucas
# Processing Record 7 of Set 27 | lagunas
# Processing Record 8 of Set 27 | marzuq
# Processing Record 9 of Set 27 | santa rosalia
# Processing Record 10 of Set 27 | oranjemund
# Processing Record 11 of Set 27 | varca
# Processing Record 12 of Set 27 | jijiga
# Processing Record 13 of Set 27 | bournemouth
# Processing Record 14 of Set 27 | tevaitoa
# Processing Record 15 of Set 27 | taoudenni
# Processing Record 16 of Set 27 | oriximina
# Processing Record 17 of Set 27 | qobustan
# Processing Record 18 of Set 27 | tarancon
# Processing Record 19 of Set 27 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 27 | kitui
# Processing Record 21 of Set 27 | gat
# Processing Record 22 of Set 27 | progreso
# Processing Record 23 of Set 27 | giyani
# Processing Record 24 of Set 27 | bud
# Processing Record 25 of Set 27 | namatanai
# Processing Record 26 of Set 27 | viligili
# City not found. Skipping...
# Processing Record 27 of Set 27 | dwarka
# Processing Record 28 of Set 27 | egra
# Processing Record 29 of Set 27 | alofi
# Processing Record 30 of Set 27 | rylsk
# Processing Record 31 of Set 27 | artyk
# City not found. Skipping...
# Processing Record 32 of Set 27 | vila velha
# Processing Record 33 of Set 27 | alotau
# City not found. Skipping...
# Processing Record 34 of Set 27 | wonthaggi
# Processing Record 35 of Set 27 | meybod
# Processing Record 36 of Set 27 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 27 | vryburg
# Processing Record 38 of Set 27 | yantal
# Processing Record 39 of Set 27 | san jeronimo
# Processing Record 40 of Set 27 | amapa
# Processing Record 41 of Set 27 | karauzyak
# City not found. Skipping...
# Processing Record 42 of Set 27 | carutapera
# Processing Record 43 of Set 27 | portland
# Processing Record 44 of Set 27 | esmeraldas
# Processing Record 45 of Set 27 | pochutla
# Processing Record 46 of Set 27 | kupang
# Processing Record 47 of Set 27 | shevchenkove
# Processing Record 48 of Set 27 | tuatapere
# Processing Record 49 of Set 27 | ledyard
# Processing Record 50 of Set 27 | abashiri
# Processing Record 1 of Set 28 | polunochnoye
# Processing Record 2 of Set 28 | pauini
# Processing Record 3 of Set 28 | chalus
# Processing Record 4 of Set 28 | dire dawa
# Processing Record 5 of Set 28 | beberibe
# Processing Record 6 of Set 28 | yerbogachen
# Processing Record 7 of Set 28 | marrakesh
# Processing Record 8 of Set 28 | borisoglebskiy
# Processing Record 9 of Set 28 | odweyne
# Processing Record 10 of Set 28 | sepolno krajenskie
# Processing Record 11 of Set 28 | ponta delgada
# Processing Record 12 of Set 28 | bell ville
# Processing Record 13 of Set 28 | hakodate
# Processing Record 14 of Set 28 | kongsberg
# Processing Record 15 of Set 28 | griffith
# Processing Record 16 of Set 28 | kachug
# Processing Record 17 of Set 28 | muravlenko
# Processing Record 18 of Set 28 | binga
# Processing Record 19 of Set 28 | sergeyevka
# Processing Record 20 of Set 28 | sungairaya
# Processing Record 21 of Set 28 | katobu
# Processing Record 22 of Set 28 | port hedland
# Processing Record 23 of Set 28 | turayf
# Processing Record 24 of Set 28 | gweta
# Processing Record 25 of Set 28 | ibotirama
# Processing Record 26 of Set 28 | ylivieska
# Processing Record 27 of Set 28 | antalaha
# Processing Record 28 of Set 28 | port blair
# Processing Record 29 of Set 28 | neiafu
# Processing Record 30 of Set 28 | parabel
# Processing Record 31 of Set 28 | cayenne
# Processing Record 32 of Set 28 | hirara
# Processing Record 33 of Set 28 | mut
# Processing Record 34 of Set 28 | price
# Processing Record 35 of Set 28 | yemtsa
# Processing Record 36 of Set 28 | pacifica
# Processing Record 37 of Set 28 | nizhniy tsasuchey
# Processing Record 38 of Set 28 | kentville
# Processing Record 39 of Set 28 | muros
# Processing Record 40 of Set 28 | marsh harbour
# Processing Record 41 of Set 28 | chiang mai
# Processing Record 42 of Set 28 | mangrol
# Processing Record 43 of Set 28 | kaduqli
# Processing Record 44 of Set 28 | carpentras
# Processing Record 45 of Set 28 | mehamn
# Processing Record 46 of Set 28 | ruteng
# Processing Record 47 of Set 28 | tavrichanka
# Processing Record 48 of Set 28 | porto velho
# Processing Record 49 of Set 28 | cartagena
# Processing Record 50 of Set 28 | udachnyy
# Processing Record 1 of Set 29 | avallon
# Processing Record 2 of Set 29 | sabang
# Processing Record 3 of Set 29 | marawi
# Processing Record 4 of Set 29 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 29 | vangaindrano
# Processing Record 6 of Set 29 | sataua
# City not found. Skipping...
# Processing Record 7 of Set 29 | bilma
# Processing Record 8 of Set 29 | port augusta
# Processing Record 9 of Set 29 | pampa
# Processing Record 10 of Set 29 | radcliff
# Processing Record 11 of Set 29 | rossano
# Processing Record 12 of Set 29 | wiang sa
# Processing Record 13 of Set 29 | taldan
# Processing Record 14 of Set 29 | klaksvik
# Processing Record 15 of Set 29 | janakpur
# Processing Record 16 of Set 29 | luganville
# Processing Record 17 of Set 29 | zachagansk
# City not found. Skipping...
# Processing Record 18 of Set 29 | zhireken
# Processing Record 19 of Set 29 | huicungo
# Processing Record 20 of Set 29 | nara
# Processing Record 21 of Set 29 | wukari
# Processing Record 22 of Set 29 | puerto penasco
# Processing Record 23 of Set 29 | ulaangom
# Processing Record 24 of Set 29 | mezen
# Processing Record 25 of Set 29 | sorland
# Processing Record 26 of Set 29 | kattivakkam
# Processing Record 27 of Set 29 | aitape
# Processing Record 28 of Set 29 | bailesti
# Processing Record 29 of Set 29 | kangshan
# Processing Record 30 of Set 29 | vao
# Processing Record 31 of Set 29 | mingguang
# Processing Record 32 of Set 29 | pontes e lacerda
# Processing Record 33 of Set 29 | verkhnetulomskiy
# Processing Record 34 of Set 29 | eldikan
# City not found. Skipping...
# Processing Record 35 of Set 29 | raikot
# Processing Record 36 of Set 29 | villazon
# Processing Record 37 of Set 29 | storslett
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

city_data_df
# Out:
#                  City      Lat       Lng  Min Temp  Max Temp  Humidity  \
# 0         Port Alfred -33.5906   26.8910     68.18     68.18        70
# 1           Nantucket  41.2835  -70.0995     55.02     57.31        85
# 2       Prince Albert  53.2001 -105.7677     35.55     35.55        64
# 3               Vaini -21.2000 -175.2000     73.56     73.56        68
# 4            Berlevag  70.8578   29.0864     22.80     24.75        86
# ..                ...      ...       ...       ...       ...       ...
# 671  Pontes E Lacerda -15.2261  -59.3353     86.20     86.20        49
# 672  Verkhnetulomskiy  68.6073   31.7962     28.13     28.53        68
# 673            Raikot  30.6500   75.6000    103.14    103.14        10
# 674          Villazon -22.0866  -65.5942     58.35     58.35         7
# 675         Storslett  69.7678   21.0247     28.40     28.40        80
#
#      Cloudiness  Wind Speed Country Current Description
# 0             1        7.00      ZA           clear sky
# 1           100       16.11      US     overcast clouds
# 2            75       16.11      CA       broken clouds
# 3            20        5.75      TO          few clouds
# 4            75       19.57      NO          light snow
# ..          ...         ...     ...                 ...
# 671          38        7.00      BR    scattered clouds
# 672          99       10.63      RU          light snow
# 673           0        6.53      IN           clear sky
# 674         100        6.31      BO     overcast clouds
# 675         100        8.05      NO     overcast clouds
#
# [676 rows x 10 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
